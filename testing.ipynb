# %%
import json

# %%
data = json.load(open("Webmap_datasources/world_pop.json", encoding='utf-8-sig'))

# %%
data
# Out:
# [{'cca2': 'CN',
#   'name': 'China',
#   'pop2022': '1448471.4000',
#   'pop2020': '1439323.776',
#   'pop2050': '1402405.170',
#   'pop2030': '1464340.159',
#   'pop2015': '1406847.870',
#   'pop2010': '1368810.615',
#   'pop2000': '1290550.765',
#   'pop1990': '1176883.674',
#   'pop1980': '1000089.235',
#   'pop1970': '827601.394',
#   'area': 9706961,
#   'Density': '149.2199',
#   'GrowthRate': '1.0029',
#   'WorldPercentage': '0.1821',
#   'rank': 1},
#  {'cca2': 'IN',
#   'name': 'India',
#   'pop2022': '1406631.7760',
#   'pop2020': '1380004.385',
#   'pop2050': '1639176.033',
#   'pop2030': '1503642.322',
#   'pop2015': '1310152.403',
#   'pop2010': '1234281.170',
#   'pop2000': '1056575.549',
#   'pop1990': '873277.798',
#   'pop1980': '698952.844',
#   'pop1970': '555189.792',
#   'area': 3287590,
#   'Density': '427.8611',
#   'GrowthRate': '1.0095',
#   'WorldPercentage': '0.1768',
#   'rank': 2},
#  {'cca2': 'US',
#   'name': 'United States',
# ...

# %%
import pandas

# %%
data1 = pandas.read_json("Webmap_datasources/data.json")

# %%
data1
# Out:
#             Name         Pop  WorldPop  GrowthRate  PopDensity
# 0           Asia  4715932231    0.5929      0.0080    146.7394
# 1         Africa  1406722629    0.1769      0.0242     46.3989
# 2         Europe   748590761    0.0941     -0.0003     32.5151
# 3  North America   601048052    0.0756      0.0075     24.7914
# 4  South America   437694443    0.0550      0.0079     24.5382
# 5        Oceania    43755226    0.0055      0.0124      5.0933
